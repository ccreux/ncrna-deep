# %% [markdown]
# # Dataset Preparation

# %% [markdown]
# ## Generate Rfam novel sequences with boundary noise

# %%
from utils.seqEncoders import *
from utils.ExpConfiguration import *
#%run seqEncoders

# Run datasets/Rfam-novel/dataset-preparation.R frst to generate fasta files

ltrain = get_labels(fastaTrain)
np.save('train_labels', ltrain)
lval = get_labels(fastaVal)
np.save('val_labels', lval)
ltest = get_labels(fastaTest)
np.save('test_labels', ltest)


# Generate sequences with boundary noise ranging among 0,25,50,75,100,..200 percents of sequence length.
for bn in bnoise:
    print("Noise = ", str(bn))
    seqTrain = get_seqs_with_bnoise(fastaTrain,nperc=bn)
    write_seqs('train_seq_bn'+str(bn)+'.fasta', seqTrain, ltrain)
    seqVal = get_seqs_with_bnoise(fastaVal,nperc=bn)
    write_seqs('val_seq_bn'+str(bn)+'.fasta', seqVal, lval)
    seqTest = get_seqs_with_bnoise(fastaTest,nperc=bn)
    write_seqs('test_seq_bn'+str(bn)+'.fasta', seqTest, ltest)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4157132/3211628379.py in <module>
#       5 # Run datasets/Rfam-novel/dataset-preparation.R frst to generate fasta files
#       6
# ----> 7 ltrain = get_labels(fastaTrain)
#       8 #np.save('train_labels', ltrain)
#       9 lval = get_labels(fastaVal)
#
# ~/Documents/ncBench/methods/ncrna-deep/utils/seqEncoders.py in get_labels(fasta_file)
#     196
#     197 def get_labels(fasta_file):
# --> 198     seq_rec = list(SeqIO.parse(fasta_file, "fasta"))
#     199     labels=[]
#     200     for i,r in enumerate(seq_rec):
#
# ~/miniconda3/envs/ncrnadeep/lib/python3.7/site-packages/Bio/SeqIO/__init__.py in parse(handle, format, alphabet)
#     603     iterator_generator = _FormatToIterator.get(format)
#     604     if iterator_generator:
# --> 605         return iterator_generator(handle)
#     606     if format in AlignIO._FormatToIterator:
#     607         # Use Bio.AlignIO to read in the alignments
#
# ~/miniconda3/envs/ncrnadeep/lib/python3.7/site-packages/Bio/SeqIO/FastaIO.py in __init__(self, source, alphabet, title2ids)
#     221             )
#     222         self.title2ids = title2ids
# --> 223         super().__init__(source, mode="t", fmt="Fasta")
#     224
#     225     def parse(self, handle):
#
# ~/miniconda3/envs/ncrnadeep/lib/python3.7/site-packages/Bio/SeqIO/Interfaces.py in __init__(self, source, alphabet, mode, fmt)
#      43             raise ValueError("The alphabet argument is no longer supported")
#      44         try:
# ---> 45             self.stream = open(source, "r" + mode)
#      46             self.should_close_stream = True
#      47         except TypeError:  # not a path, assume we received a stream
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datasets/Rfam-novel/x_train.fasta'

# %% [markdown]
# ## Generate encoded Rfam novel sequences and applies the corresponding padding schema

# %%
from utils.seqEncoders import *
from utils.ExpConfiguration import *
#%run seqEncoders

# For each sequence with boundary noise bn a padding is added and an encoder is applied

for p in padds:
    for bn in bnoise:
        seqTrain = get_seqs_with_bnoise('train_seq_bn'+str(bn)+'.fasta',nperc=0)
        seqVal = get_seqs_with_bnoise('val_seq_bn'+str(bn)+'.fasta',nperc=0)
        seqTest = get_seqs_with_bnoise('test_seq_bn'+str(bn)+'.fasta',nperc=0)
        for en in seqEncoders:
            print("Padding = ",p,", Noise = ", str(bn),", Encoder = ",en['filename'])
            train_seq = encode_seqs(seqTrain,enc=en['enc'],encparam=en['param'+str(bn)],padding=p)
            val_seq = encode_seqs(seqVal,enc=en['enc'],encparam=en['param'+str(bn)],padding=p)
            test_seq = encode_seqs(seqTest,enc=en['enc'],encparam=en['param'+str(bn)],padding=p)
            np.save('train_' +  en['filename'] + '_' + p + "_" + str(bn) + '_seq', train_seq)
            np.save('val_' + en['filename'] + '_' + p + "_" + str(bn) +'_seq', val_seq)
            np.save('test_' + en['filename'] + '_' + p + "_" + str(bn) +'_seq', test_seq)
# Out:
# Padding =  random , Noise =  0 , Encoder =  3mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  0 , Encoder =  2mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  0 , Encoder =  1mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  0 , Encoder =  Snake
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  0 , Encoder =  Morton
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  0 , Encoder =  Hilbert
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  25 , Encoder =  3mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  25 , Encoder =  2mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  25 , Encoder =  1mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  25 , Encoder =  Snake
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  25 , Encoder =  Morton
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  25 , Encoder =  Hilbert
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  50 , Encoder =  3mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  50 , Encoder =  2mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  50 , Encoder =  1mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  50 , Encoder =  Snake
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  50 , Encoder =  Morton
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  50 , Encoder =  Hilbert
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  75 , Encoder =  3mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  75 , Encoder =  2mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  75 , Encoder =  1mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  75 , Encoder =  Snake
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  75 , Encoder =  Morton
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  75 , Encoder =  Hilbert
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  100 , Encoder =  3mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  100 , Encoder =  2mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  100 , Encoder =  1mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  100 , Encoder =  Snake
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  100 , Encoder =  Morton
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  100 , Encoder =  Hilbert
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  125 , Encoder =  3mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  125 , Encoder =  2mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  125 , Encoder =  1mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  125 , Encoder =  Snake
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  125 , Encoder =  Morton
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  125 , Encoder =  Hilbert
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  150 , Encoder =  3mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  150 , Encoder =  2mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  150 , Encoder =  1mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  150 , Encoder =  Snake
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  150 , Encoder =  Morton
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  150 , Encoder =  Hilbert
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  175 , Encoder =  3mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  175 , Encoder =  2mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  175 , Encoder =  1mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  175 , Encoder =  Snake
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  175 , Encoder =  Morton
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  175 , Encoder =  Hilbert
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  200 , Encoder =  3mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  200 , Encoder =  2mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  200 , Encoder =  1mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  200 , Encoder =  Snake
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  200 , Encoder =  Morton
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  random , Noise =  200 , Encoder =  Hilbert
#  Done 105864 total records
#  Done 25342 total records
# Padding =  constant , Noise =  0 , Encoder =  3mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  0 , Encoder =  2mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  0 , Encoder =  1mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  0 , Encoder =  Snake
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  0 , Encoder =  Morton
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  0 , Encoder =  Hilbert
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  25 , Encoder =  3mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  25 , Encoder =  2mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  25 , Encoder =  1mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  25 , Encoder =  Snake
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  25 , Encoder =  Morton
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  25 , Encoder =  Hilbert
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  50 , Encoder =  3mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  50 , Encoder =  2mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  50 , Encoder =  1mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  50 , Encoder =  Snake
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  50 , Encoder =  Morton
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  50 , Encoder =  Hilbert
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  75 , Encoder =  3mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  75 , Encoder =  2mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  75 , Encoder =  1mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  75 , Encoder =  Snake
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  75 , Encoder =  Morton
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  75 , Encoder =  Hilbert
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  100 , Encoder =  3mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  100 , Encoder =  2mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  100 , Encoder =  1mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  100 , Encoder =  Snake
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  100 , Encoder =  Morton
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  100 , Encoder =  Hilbert
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  125 , Encoder =  3mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  125 , Encoder =  2mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  125 , Encoder =  1mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  125 , Encoder =  Snake
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  125 , Encoder =  Morton
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  125 , Encoder =  Hilbert
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  150 , Encoder =  3mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  150 , Encoder =  2mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  150 , Encoder =  1mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  150 , Encoder =  Snake
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  150 , Encoder =  Morton
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  150 , Encoder =  Hilbert
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  175 , Encoder =  3mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  175 , Encoder =  2mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  175 , Encoder =  1mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  175 , Encoder =  Snake
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  175 , Encoder =  Morton
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  175 , Encoder =  Hilbert
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  200 , Encoder =  3mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  200 , Encoder =  2mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  200 , Encoder =  1mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  200 , Encoder =  Snake
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  200 , Encoder =  Morton
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  constant , Noise =  200 , Encoder =  Hilbert
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  0 , Encoder =  3mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  0 , Encoder =  2mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  0 , Encoder =  1mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  0 , Encoder =  Snake
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  0 , Encoder =  Morton
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  0 , Encoder =  Hilbert
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  25 , Encoder =  3mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  25 , Encoder =  2mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  25 , Encoder =  1mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  25 , Encoder =  Snake
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  25 , Encoder =  Morton
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  25 , Encoder =  Hilbert
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  50 , Encoder =  3mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  50 , Encoder =  2mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  50 , Encoder =  1mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  50 , Encoder =  Snake
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  50 , Encoder =  Morton
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  50 , Encoder =  Hilbert
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  75 , Encoder =  3mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  75 , Encoder =  2mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  75 , Encoder =  1mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  75 , Encoder =  Snake
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  75 , Encoder =  Morton
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  75 , Encoder =  Hilbert
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  100 , Encoder =  3mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  100 , Encoder =  2mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  100 , Encoder =  1mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  100 , Encoder =  Snake
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  100 , Encoder =  Morton
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  100 , Encoder =  Hilbert
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  125 , Encoder =  3mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  125 , Encoder =  2mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  125 , Encoder =  1mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  125 , Encoder =  Snake
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  125 , Encoder =  Morton
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  125 , Encoder =  Hilbert
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  150 , Encoder =  3mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  150 , Encoder =  2mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  150 , Encoder =  1mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  150 , Encoder =  Snake
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  150 , Encoder =  Morton
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  150 , Encoder =  Hilbert
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  175 , Encoder =  3mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  175 , Encoder =  2mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  175 , Encoder =  1mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  175 , Encoder =  Snake
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  175 , Encoder =  Morton
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  175 , Encoder =  Hilbert
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  200 , Encoder =  3mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  200 , Encoder =  2mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  200 , Encoder =  1mer
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  200 , Encoder =  Snake
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  200 , Encoder =  Morton
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records
# Padding =  new , Noise =  200 , Encoder =  Hilbert
#  Done 105864 total records
#  Done 17324 total records
#  Done 25342 total records

# %% [markdown]
# ## Generate Random test sequences preserving di-nucleotide freq to test for rejection

# %%
from utils.seqEncoders import *
from utils.ExpConfiguration import *

for nt in t:
    print("t = ", str(nt))
    nfseqTest = get_nonfunctional_seqs(fastaTest,t=nt)
    write_seqs('test_rndseq_t'+str(nt)+'.fasta', nfseqTest,['RND']*len(nfseqTest))
# Out:
# t =  1
# t =  2
# t =  5
# t =  10

# %% [markdown]
# ## Generate encoded RNAGCN/nRC sequences and applies the corresponding padding schema

# %%
# Generate sequences from RNAGCN nRC datasets
from utils.ExpConfiguration import *
from utils.seqEncoders import *
# redefine encoders to adapt to new sequence lengths
seqEncoders = (
               {'enc' : seq2Snake,
                'filename' : 'Snake',
                'param0' : [[28,28],['A','T','C','G']]},
               {'enc' : seq2Hilbert,
                'filename' : 'Hilbert',
                'param0' : [[32,32],['A','T','C','G']]},
               {'enc' : seq2Morton,
                'filename' : 'Morton',
                'param0' : [[32,32],['A','T','C','G']]},
               {'enc' : seq2Kmer,
                'filename' : '1mer',
                'param0' : [[770],1,['A','T','C','G']]},
               {'enc' : seq2Kmer,
                'filename' : '2mer',
                'param0' : [[385],2,['A','T','C','G']]},
               {'enc' : seq2Kmer,
                'filename' : '3mer',
                'param0' : [[257],3,['A','T','C','G']]}
               )

fastaTrain='datasets/nRC-public/dataset_nRC_train.fasta'
fastaTest='datasets/nRC-public/dataset_nRC_test.fasta'

ltrain = get_labels(fastaTrain)
np.save('encoded_data/dataset_nRC_train_labels', ltrain)
ltest = get_labels(fastaTest)
np.save('encoded_data/dataset_nRC_test_labels', ltest)


seqTrain = get_seqs_with_bnoise(fastaTrain,nperc=0)
write_seqs('encoded_data/dataset_nRC_train_seq.fasta', seqTrain, ltrain)
seqTest = get_seqs_with_bnoise(fastaTest,nperc=0)
write_seqs('encoded_data/dataset_nRC_test_seq.fasta', seqTest, ltest)       
        

# Generate encoded sequences with padding among new,constant and random
for p in padds:
    for en in seqEncoders:
        print("Padding = ",p,", Encoder = ",en['filename'])
        print(en['filename'],p)
        train_seq = encode_seqs(seqTrain,enc=en['enc'],encparam=en['param0'],padding=p)
        test_seq = encode_seqs(seqTest,enc=en['enc'],encparam=en['param0'],padding=p)
        np.save('encoded_data/dataset_nRC_train_' + en['filename'] + '_' + p + '_seq', train_seq)
        np.save('encoded_data/dataset_nRC_test_' + en['filename'] + '_' + p + '_seq', test_seq)
# Out:
# Padding =  random , Encoder =  Snake
# Snake random
#  Done 6160 total records
#  Done 2529 total records
# Padding =  random , Encoder =  Hilbert
# Hilbert random
#  Done 6160 total records
#  Done 2529 total records
# Padding =  random , Encoder =  Morton
# Morton random
#  Done 6160 total records
#  Done 2529 total records
# Padding =  random , Encoder =  1mer
# 1mer random
#  Done 6160 total records
#  Done 2529 total records
# Padding =  random , Encoder =  2mer
# 2mer random
#  Done 6160 total records
#  Done 2529 total records
# Padding =  random , Encoder =  3mer
# 3mer random
#  Done 6160 total records
#  Done 2529 total records
# Padding =  constant , Encoder =  Snake
# Snake constant
#  Done 6160 total records
#  Done 2529 total records
# Padding =  constant , Encoder =  Hilbert
# Hilbert constant
#  Done 6160 total records
#  Done 2529 total records
# Padding =  constant , Encoder =  Morton
# Morton constant
#  Done 6160 total records
#  Done 2529 total records
# Padding =  constant , Encoder =  1mer
# 1mer constant
#  Done 6160 total records
#  Done 2529 total records
# Padding =  constant , Encoder =  2mer
# 2mer constant
#  Done 6160 total records
#  Done 2529 total records
# Padding =  constant , Encoder =  3mer
# 3mer constant
#  Done 6160 total records
#  Done 2529 total records
# Padding =  new , Encoder =  Snake
# Snake new
#  Done 6160 total records
#  Done 2529 total records
# Padding =  new , Encoder =  Hilbert
# Hilbert new
#  Done 6160 total records
#  Done 2529 total records
# Padding =  new , Encoder =  Morton
# Morton new
#  Done 6160 total records
#  Done 2529 total records
# Padding =  new , Encoder =  1mer
# 1mer new
#  Done 6160 total records
#  Done 2529 total records
# Padding =  new , Encoder =  2mer
# 2mer new
#  Done 6160 total records
#  Done 2529 total records
# Padding =  new , Encoder =  3mer
# 3mer new
#  Done 6160 total records
#  Done 2529 total records
